# %% [markdown]
# Generating Random Numbers

# %%
import random
# random.seed(1)
print(f'random.randint(3,6) = {random.randint(3,6)}')
print(f'random.randrange(3,6) = {random.randrange(3,6)}')
print(f'random.uniform(3, 6) = {random.uniform(3, 6)}')
print(f'random.random() = {random.random()}')
print(f'random.choice("ABCDEFG") = {random.choice("ABCDEFG")}')
# Out:
# random.randint(3,6) = 4
# random.randrange(3,6) = 5
# random.uniform(3, 6) = 5.542301210811698
# random.random() = 0.763774618976614
# random.choice("ABCDEFG") = C

# %%
result = random.choice('HT')
print(result)

d1 = random.randint(1,6)
d2 = random.randint(1,6)
print(d1 + d2)

d3 = random.randint(2,12)
print(d3)
# Out:
# T
# 3
# 9

# %% [markdown]
# for loop demonstration

# %%
for k in range(5):
  print('hello')

for k in range(5):
  print(k, end = ' ')
print()

for k in range(5):
  print(k, k**2)

alphabet = 'abcdefghijklmnopqrstuvwxyz'
for letter in alphabet:
  print(letter , end = ' ')

print()
for letter in alphabet:
  print(ord(letter) , end = ' ')

print()
print('goodbye')

# %% [markdown]
# Generating Random Numbers

# %%
import random
print("random.random()")
# Generate 5 random real numbers in the interval [0, 1)
for k in range(5):
  print(random.random())

print("\nrandom.uniform(5, 12)")
# Generate 5 random real numbers in the interval [5, 12)
for k in range(5):
  print(random.uniform(5, 12))

print("\nrandom.randint(1, 6)")
# Generate 5 random integers in the interval [1, 6] (1 and 6 are both included)
# Good for simulating the roll of a 6-sided die
for k in range(15):
  print(random.randint(1, 6), end = ' ')

print("\nrandom.randrange(1, 6)")
# Generate 5 random integers in the interval [1, 6) (6 is not possible)
for k in range(15):
  print(random.randrange(1, 6), end = ' ')

print("\nrandom.choice('ACTG')")
# Generate 5 random selections from the string "ACTG".  Good for generating random dna
for k in range(5):
  print(random.choice('ACTG'), end = ' ')

# %%
# Flip a coin
result = random.choice(['head', 'tail'])

result2 = random.choice('HT')
result3 = random.choice('HeadTail')
for k in range(10):
  result = random.choice(['head', 'tail'])
  result2 = random.choice('HT')
  result3 = random.choice('HeadTail')
  print(f'result = {result}, result2 = {result2}, result3 = {result3}')

# %% [markdown]
# Roll dice

# %%
d1 = random.randint(1, 6)
d2 = random.randint(1, 6)
print(f'd1 {d1}  and  d2 {d2}  gives {d1 + d2} ')

# %% [markdown]
# Test a trig identity at random points in the interval [0, 2pi)
# Demonstrates difficulty in using testing for equality within float type

# %%
import random, math
count = 0
numTrials = 100
for k in range(numTrials):
  x = random.uniform(0, 2*math.pi)
  if round(math.sin(x)**2 + math.cos(x)**2,10) != 1:
    print("identity fails at x =" , x, math.sin(x)**2 + math.cos(x)**2)
    count = count + 1

print(count, 'failures in', numTrials, 'trials')
# Out:
# 0 failures in 100 trials

# %% [markdown]
# Use round to test for equality with 8 digits

# %%
import random, math
count = 0
numTrials = 1000
for k in range(numTrials):
  x = random.uniform(0, 2*math.pi)
  if round(math.sin(x)**2 + math.cos(x)**2, 10) != 1:
    print("identity fails at x =" , x, math.sin(x)**2 + math.cos(x)**2)
    count = count + 1

print(count, 'failures in', numTrials, 'trials')

# %% [markdown]
# # Classwork for September 5
#
# 1.  Write a program to drill a person (the user)  on factoring  numbers in the range 4 to 100.
# Your program should:
# Generate a random integer in the range 4 to 100, call it c
# Prompt the user to enter two non-trivial factors  for c; call them a and b
# Test each of the values a and b  to see if it is a factor of c
# Give detailed feedback – telling the user if a is a factor, if b is a factor and if a * b is c.
# What do you think should happen if the randomly generated number is a prime number?
# After you get this to work, surround your solution in a for loop that repeats the drill, and compute a score for the user based on how many correct factors they found.
# •	If a is a non-trivial factor of c , add 1 to the score.
# •	If b is a non-trivial factor of c, add 1 to the score.
# •	If a*b ==c, add 2 to the score.
# So, a user will get 4 points for a correct non-trivial factorization.  If c is prime, the maximum possible score is 2.
#
#
# 2.  Randomly generate the coordinates for a point in x-y plane, with the restriction that x and y both have absolute value less than or equal to 1.  (So, your program will generate two floating point numbers in the interval [-1, 1]).  Then test to see where the point falls in relation to the unit circle – report whether the point falls inside the unit circle, on the unit circle, or outside the unit circle.
# (The unit circle is a circle of radius one centered at the origin.  It is given by the equation x^2+y^2=1.)
# Let me know if you finish this and I will suggest how to extend this exercise

# %%
# Generate a random number in the range [4, 100]
# c = random.randint(4,101)
# a = int(input('Enter one non-trivial factor for', c))
# b = int(input('Enter a second non-trivial factor for', c))

# if c % a == 0:
#   print(f'{a} is a factor of {c}!')
# if c % b == 0:
#   print(f'{b} is a factor of {c}!')
# if a * b == c:
#   print(f'Your two factors multiply to output {c}')

player_score = 0
for i in range(3):
  c = random.randint(4,101)
  print(f'The random number is {c}')
  a = int(input('Enter one non-trivial factor for the random number: '))
  b = int(input('Enter a second non-trivial factor for the random number: '))

  if c % a == 0 and a != c and a != 1:
    print(f'{a} is a factor of {c}!')
    player_score+=1
  if c % b == 0 and b != c and b != 1:
    print(f'{b} is a factor of {c}!')
    player_score+=1
  if a * b == c:
    print(f'Your two factors multiply to output {c}')
    player_score+=2
print(f'Your score is {player_score}')

# Display it


# read in user's guesses at factors
# Out:
# The random number is 52
# Enter one non-trivial factor for the random number: 2
# Enter a second non-trivial factor for the random number: 26
# 2 is a factor of 52!
# 26 is a factor of 52!
# Your two factors multiply to output 52
# The random number is 74
# Enter one non-trivial factor for the random number: 2
# Enter a second non-trivial factor for the random number: 37
# 2 is a factor of 74!
# 37 is a factor of 74!
# Your two factors multiply to output 74
# The random number is 48
# Enter one non-trivial factor for the random number: 2
# Enter a second non-trivial factor for the random number: 24
# 2 is a factor of 48!
# 24 is a factor of 48!
# Your two factors multiply to output 48
# 12
